# %%
import matplotlib.pyplot as plt
import numpy as np
from data_visiable.randomwalk import RandomWalk

rw = RandomWalk()
rw.fill_walk()

plt.figure(dpi=128, facecolor='white', figsize=(7,6))
plt.axis('off')

plt.plot(
    rw.x_values, rw.y_values,
    linewidth=3
)

plt.show()
